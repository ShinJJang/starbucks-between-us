# %% [markdown]
# ### 우리 사이 스벅 - 아이디어 검증
# [부동산 - 스타벅스 매장 데이터와 지도](https://financedata.github.io/posts/python_starbucks_map.html)에서 인사이트를 얻었고, 아래는 그 코드를 변경하여 실행해보았습니다.
#
# - [Folium Quick Start](http://folium.readthedocs.io/en/latest/quickstart.html)
# - [Folium API Doc](http://python-visualization.github.io/folium/docs-master)

# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize
import folium

API_KEY = 'C75A0E7E-CB1F-300E-8032-95C597F3E226'

# %%
# 주소를 좌표로 변환
def get_geoloc(addr):
    URI = f'http://apis.vworld.kr/new2coord.do?q={addr}&apiKey={API_KEY}&domain=http://map.vworld.kr/&output=json'
    r = requests.get(URI)
    r_j = r.json()
    # TODO - 예외처리(없는 주소, API key 오류)
    location = (float(r_j['EPSG_4326_Y']), float(r_j['EPSG_4326_X']))
    return location

# %%
from collections import namedtuple
Geoloc = namedtuple('Geoloc', ['loc', 'tag'])

# %% [markdown]
# ### 각자의 출발지 주소를 좌표로 변환

# %%
# namedtuple을 이용하여 (주소, 태그)를 (좌표, 태그)로 변경
addr_list = [('서울시 강남구 봉은사로7길 20-1', '루카집'), ('서울시 강남구 테헤란로10길 10', 'Gin'), ('서울시 광진구 천호대로116길 108-11', '빵형')]
geoloc_list = [Geoloc(get_geoloc(addr), tag) for addr, tag in addr_list]
geoloc_list
# Out:
# [Geoloc(loc=(37.507038913, 127.027463426), tag='루카집'),
#  Geoloc(loc=(37.498402165, 127.032264518), tag='Gin'),
#  Geoloc(loc=(37.553302917, 127.081286591), tag='빵형')]

# %% [markdown]
# ### 출발지 좌표들의 무게 중심 좌표를 구함

# %%
def get_center_of_mass(loc_list):
    count = len(loc_list)
    sum_lat = 0
    sum_lot = 0
    for loc in loc_list:
        sum_lat += loc[0]
        sum_lot += loc[1]
    return (sum_lat/count, sum_lot/count)

# %%
center_of_mass = get_center_of_mass([geoloc.loc for geoloc in geoloc_list])
print(center_of_mass)
# mac 계산기로 직접 계산해봄
mac_com = (37.5195813317, 127.047004845)
print(mac_com)
# 유의미한 차이가 없음을 확인함
# Out:
# (37.51958133166667, 127.047004845)
# (37.5195813317, 127.047004845)

# %%
import random

map_osm = folium.Map(location=center_of_mass, zoom_start=13)
for loc, tag in geoloc_list:
    r = lambda: random.randint(0,255)
    random_color = '#%02X%02X%02X' % (r(),r(),r())
    folium.CircleMarker(loc, popup=tag, radius=300, color=random_color, fill=True, fill_color=random_color).add_to(map_osm)

folium.Marker(center_of_mass, popup='무게 중심', icon=folium.Icon(icon='cloud')).add_to(map_osm)
folium.CircleMarker(center_of_mass, popup='무게 중심', radius=100, color='#ff86cc', fill=True, fill_color='#ff86cc').add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - 음... 세 원의 교차 지점에 무게 중심이 나올 줄 알았다. 무게중심에 대해서 더 알아봐야겠다.
# - 그리고 Circle marker의 radius가 zoom state에 따라 상대적이라서 특정 줌 상태에서만 intersection을 보여주고 있음
# - 절대값 옵션이 있는지 확인해보고, 또는 새로 마커를 그리거나 업데이트 하는 방법을 고려해봐야겠다.

# %% [markdown]
# ### 서울시 스타벅스 정보 가져오기

# %%
from folium import plugins

data_seoul = {
    'ins_lat': '33.4996213', # 제주 시청의 좌표
    'ins_lng': '126.5311884',
    'p_sido_cd':'01', # 01=서울시, 08=경기 ... 16=제주
    'p_gugun_cd':'',  # 세부지역 (지정하지 않으면 시/도 전체)
    'in_biz_cd':'',
    'set_date':'',
    'iend':'1000',
}
    
url = 'https://www.istarbucks.co.kr/store/getStore.do'
r = requests.post(url, data=data_seoul)
df_seoul = json_normalize(json.loads(r.text), 'list')
df_seoul = df_seoul[['s_name', 'lat', 'lot', 'sido_name', 'gugun_name', 'doro_address', 'tel']]
df_seoul.head(20)
# Out:
#       s_name          lat                 lot sido_name gugun_name  \
# 0       금천시흥    37.448624          126.903183        서울        금천구
# 1     청계산입구역    37.447323          127.056250        서울        서초구
# 2       금천독산     37.46914          126.895246        서울        금천구
# 3      독산사거리    37.471511          126.898775        서울        금천구
# 4      하이브랜드  37.46330766         127.0368447        서울        서초구
# 5     가산브이타워    37.477221          126.883683        서울        금천구
# 6     W-Mall  37.47730499         126.8876908        서울        금천구
# 7     마리오아울렛    37.478701          126.885076        서울        금천구
# 8     가산그레이트   37.4794491  126.88747680000006        서울        금천구
# 9      가산디지털   37.4798346  126.88249969999992        서울        금천구
# 10  가산디지털단지역    37.481324          126.883779        서울        금천구
# 11     낙성대DT    37.476169          126.965005        서울        관악구
# 12    구로하이엔드    37.481618          126.893136        서울        구로구
# 13      신림DT    37.480935          126.908407        서울        관악구
# 14        사당     37.47601          126.980997        서울        관악구
# 15     사당로데오   37.4772752  126.98216049999996        서울        서초구
# 16      구로호텔   37.4831293  126.89885909999998        서울        구로구
# 17   구로디지털타워    37.483432          126.896480        서울        구로구
# 18       사당역  37.47849216         126.9813456        서울        동작구
# 19     구로에이스  37.48448329         126.8944957        서울        구로구
#
#                                    doro_address           tel
# 0                      서울특별시 금천구 시흥대로 164 (시흥동)   02-805-3360
# 1                      서울특별시 서초구 청계산로 203 (신원동)   02-577-3253
# 2                        서울특별시 금천구 두산로 66 (독산동)   02-758-8765
# 3                      서울특별시 금천구 시흥대로 426 (독산동)   02-838-3444
# 4              서울특별시 서초구 매헌로 16, 리빙관 101호 (양재동)  02-2155-4117
# 5                   서울특별시 금천구 가산디지털1로 128 (가산동)   02-758-8371
# 6                      서울특별시 금천구 디지털로 188 (가산동)   02-758-8196
# 7                     서울특별시 금천구 디지털로9길 23 (가산동)   02-758-8542
# 8        서울특별시 금천구 디지털로9길 32, 갑을그레이트밸리 1층 (가산동)   02-758-8346
# 9                   서울특별시 금천구 가산디지털1로 168 (가산동)   02-758-8147
# 10                      서울특별시 금천구 벚꽃로 298 (가산동)  02-2083-8302
# 11                   서울특별시 관악구 남부순환로 1948 (봉천동)   02-872-3249
# 12  서울특별시 구로구 디지털로26길 5, 에이스하이엔드타워1차 103호 (구로동)   02-758-8340
# 13                   서울특별시 관악구 남부순환로 1419 (신림동)   02-851-3283
# 14                      서울특별시 관악구 남부순환로 2082-25   02-758-8721
# 15                      서울특별시 서초구 방배천로 5-4(방배동)   02-758-8953
# 16          서울특별시 구로구 디지털로32길 72, 구로호텔 1층 (구로동)   02-758-8555
# 17                   서울특별시 구로구 디지털로32길 30 (구로동)  02-2103-5088
# 18           서울특별시 동작구 동작대로 21, 양지빌딩 1-3층 (사당동)   02-758-8311
# 19     서울특별시 구로구 디지털로 285, 에이스트윈타워1차 103호 (구로동)   02-758-8161

# %% [markdown]
# ### 지도에 스타벅스 지점을 묶어서 표시
# - marker cluster를 사용

# %%
markerCluster = folium.plugins.MarkerCluster().add_to(map_osm)
for ix, row in df_seoul.iterrows():
    loc = (float(row['lat']), float(row['lot']))
#     print(f'{loc} {row["s_name"]} {type(row["lat"])}')
    folium.Marker(loc, popup=row['s_name']).add_to(markerCluster)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 번외 - 좌표 간의 거리 구하기

# %%
from math import sin, cos, sqrt, atan2, radians

# approximate radius of earth in km
R = 6373.0

lat1 = radians(52.2296756)
lon1 = radians(21.0122287)
lat2 = radians(52.406374)
lon2 = radians(16.9251681)

dlon = lon2 - lon1
dlat = lat2 - lat1

a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
c = 2 * atan2(sqrt(a), sqrt(1 - a))

distance = R * c

print("Result:", distance)
print("Should be:", 278.546, "km")
# Out:
# Result: 278.54558935106695
# Should be: 278.546 km

# %% [markdown]
# ### 이전 코드

# %%
addr_list = [('서울시 강남구 봉은사로7길 20-1', '루카집'), ('과천시 별양로 85', '호선생님')]
서울_시청=(37.56629, 126.979808)
map_osm = folium.Map(location=서울_시청, zoom_start=13)
for addr, tag in addr_list:
    API_KEY = '767B7ADF-10BA-3D86-AB7E-02816B5B92E9'
    URI = 'http://apis.vworld.kr/new2coord.do?q=%s&apiKey=%s&domain=http://map.vworld.kr/&output=json' % (addr, API_KEY)
    r =requests.get(URI)
    r_j = r.json()

    print(r_j)
    location = (float(r_j['EPSG_4326_Y']), float(r_j['EPSG_4326_X']))
    print("%s %s" % (location, tag))
    folium.CircleMarker(location, popup=tag, radius=200, color='#3186cc',
                    fill_color='#3186cc',).add_to(map_osm)
    
map_osm

from folium import plugins

data = {
    'ins_lat': '33.4996213', # 제주 시청의 좌표
    'ins_lng': '126.5311884',
    'p_sido_cd':'08', # 01=서울시, 08=경기 ... 16=제주
    'p_gugun_cd':'',  # 세부지역 (지정하지 않으면 시/도 전체)
    'in_biz_cd':'',
    'set_date':'',
    'iend':'1000',
}
    
url = 'https://www.istarbucks.co.kr/store/getStore.do'
r = requests.post(url, data=data)
df = json_normalize(json.loads(r.text), 'list')

markerCluster = folium.plugins.MarkerCluster().add_to(map_osm)
for ix, row in df.iterrows():
    location = (float(row['lat']), float(row['lot']))
    print("%s %s %s" % (location, row['s_name'], type(row['lat'])))
    folium.Marker(location, popup=row['s_name']).add_to(markerCluster)

map_osm
# Out:
# {'EPSG_4326_X': '127.027463426', 'EPSG_4326_Y': '37.507038913', 'JUSO': '서울특별시 강남구 봉은사로7길 20-1'}
# (37.507038913, 127.027463426) 루카집
# {'EPSG_4326_X': '126.994403377', 'EPSG_4326_Y': '37.426134902', 'JUSO': '경기도 과천시 별양로 85 (주공아파트)'}
# (37.426134902, 126.994403377) 호선생님
# (36.9547073, 127.04916030000004) 평택험프리 <class 'str'>
# (36.957324, 127.035458) 평택험프리 트룹몰 <class 'str'>
# (36.960753, 127.037315) 평택험프리 메인몰 <class 'str'>
# (36.99159, 127.08524) 평택AK플라자 <class 'str'>
# (36.9918478, 127.08850410000002) 평택로데오 <class 'str'>
# (37.007599, 127.270743) 안성중앙로 <class 'str'>
# (37.066397, 127.062939) 평택송탄 <class 'str'>
# (37.089517, 127.05814) 오산AB <class 'str'>
# (37.1426829, 127.0766272) 오산IC DT <class 'str'>
# (37.1486248, 127.0741288) 오산시청 <class 'str'>
# (37.197988, 127.098448) 동탄역 <class 'str'>
# (37.201584, 127.073193) 동탄 <class 'str'>
# (37.204774, 127.071884) 동탄광장 <class 'str'>
# (37.2082443, 127.0638898) 동탄센트럴파크 <class 'str'>
# (37.21261, 127.038187) 화성병점DT <class 'str'>
# (37.20663, 127.111333) 동탄영천 <class 'str'>
# (37.214754, 127.079887) 동탄이마트 <class 'str'>
# (37.2343091, 127.06300199999998) 신영통DT <class 'str'>
# (37.246345, 126.964025) 수원권선 DT <class 'str'>
# (37.246668, 127.030958) 수원권선 <class 'str'>
# (37.245241, 127.055904) 수원망포역 <class 'str'>
# (37.24582770000001, 127.05133999999998) 수원망포DT <class 'str'>
# (37.24626, 127.047864) 수원트레이더스 <class 'str'>
# (37.249907, 127.021517) 수원이마트 <class 'str'>
# (37.247951, 127.076749) 경희대국제캠퍼스 <class 'str'>
# (37.234764, 127.202928) 용인처인구청 <class 'str'>
# (37.24029, 127.170935) 용인시청DT <class 'str'>
# (37.2592235, 127.0313138) 수원이비스 <class 'str'>
# (37.255675, 127.074321) 수원영통 <class 'str'>
# (37.261414, 127.031229) 수원시청 <class 'str'>
# (37.26748423, 127.0028636) 수원매산 <class 'str'>
# (37.265499, 127.032902) 수원인계 <class 'str'>
# (37.267938, 127.027948) 수원인계DT <class 'str'>
# (37.267257, 127.074502) 수원IC DT <class 'str'>
# (37.271122, 127.035213) 수원KBS DT <class 'str'>
# (37.2781099, 127.03394960000003) 동수원DT <class 'str'>
# (37.27105, 127.126134) 강남대 <class 'str'>
# (37.279696, 127.04334) 아주대 <class 'str'>
# (37.274595, 127.141221) 용인동백DT <class 'str'>
# (37.300847, 126.838212) 안산한양대 <class 'str'>
# (37.303177, 126.812842) 고잔이마트 <class 'str'>
# (37.281689, 127.110142) 용인기흥구청 <class 'str'>
# (37.290374, 127.049582) 수원광교 <class 'str'>
# (37.297286, 126.982671) 수원천천 <class 'str'>
# (37.298935, 126.971577) 수원성균관대 <class 'str'>
# (37.308754, 126.851175) 안산한대앞역 <class 'str'>
# (37.310298, 126.830517) 안산문화광장 <class 'str'>
# (37.2962004, 127.0465643) 광교이마트 <class 'str'>
# (37.2947324, 127.11029259999998) 용인마북DT <class 'str'>
# (37.29882, 127.06947) 광교중앙로 <class 'str'>
# (37.31723608, 126.8374694) 안산중앙역 <class 'str'>
# (37.318176, 126.833639) 안산고잔 <class 'str'>
# (37.318868, 126.826297) 안산상공회의소 <class 'str'>
# (37.318899, 126.837464) 안산중앙 <class 'str'>
# (37.263504, 127.407795) 마장휴게소 <class 'str'>
# (37.25251, 127.489933) 이천하이닉스 <class 'str'>
# (37.305434, 127.105468) 구성트레이더스 <class 'str'>
# (37.3312008, 126.77202720000003) 안산트레이더스 <class 'str'>
# (37.314801, 127.078772) 수지성복DT <class 'str'>
# (37.2413127, 127.61255559999995) 여주P.아울렛입구 <class 'str'>
# (37.24272107, 127.6126336) 여주P.아울렛 <class 'str'>
# (37.31965, 127.083677) 수지이마트 <class 'str'>
# (37.344718, 126.737045) 시화로데오 <class 'str'>
# (37.320017, 127.11084) 용인보정 <class 'str'>
# (37.322526, 127.095525) 수지풍덕천 <class 'str'>
# (37.278191, 127.446323) 이천터미널 <class 'str'>
# (37.32500393, 127.1081332) 신세계경기 <class 'str'>
# (37.32500393, 127.1081332) 죽전CGV <class 'str'>
# (37.3253735, 127.1099255) 죽전이마트 <class 'str'>
# (37.331506, 127.12479) 죽전 <class 'str'>
# (37.335988, 127.09101) 수지동천 <class 'str'>
# (37.299106, 127.407841) 이천사음DT <class 'str'>
# (37.338617, 127.109225) 오리역 <class 'str'>
# (37.340016, 127.108332) 오리역삼거리 <class 'str'>
# (37.358087, 126.931956) 산본역 <class 'str'>
# (37.369549, 126.730301) 배곧신도시 <class 'str'>
# (37.36061352, 126.9317436) 산본 <class 'str'>
# (37.349605, 127.108302) 미금역사거리 <class 'str'>
# (37.350318, 127.106655) 미금역 <class 'str'>
# (37.365491, 126.929426) 산본동 <class 'str'>
# (37.3504033, 127.12446169999998) 분당서울대병원1 <class 'str'>
# (37.366561, 126.956011) 안양호계DT <class 'str'>
# (37.351934, 127.123312) 분당서울대병원4 <class 'str'>
# (37.379754, 126.736396) 시흥P.아울렛 3F <class 'str'>
# (37.379754, 126.736396) 시흥P.아울렛 1F <class 'str'>
# (37.35885, 127.119777) 분당이마트 <class 'str'>
# (37.3608179, 127.10758269999997) 정자아데나 <class 'str'>
# (37.36329, 127.114074) 정자동 <class 'str'>
# (37.365045, 127.106119) 정자 <class 'str'>
# (37.36682377, 127.1067347) 정자역 <class 'str'>
# (37.383006, 126.959848) 평촌호계 <class 'str'>
# (37.3705048, 127.10557389999997) 정자상떼뷰 <class 'str'>
# (37.371675, 127.107214) 분당정자 <class 'str'>
# (37.389849, 126.949818) 범계역 <class 'str'>
# (37.37782763, 127.1138859) 수내역 <class 'str'>
# (37.391494, 126.955122) 범계로데오 <class 'str'>
# (37.3925328, 126.942869) 안양비산DT <class 'str'>
# (37.39227643, 126.9565229) 평촌아크로 <class 'str'>
# (37.37948523, 127.114173) 수내 <class 'str'>
# (37.3929425, 126.9607148) 평촌로데오 <class 'str'>
# (37.380601, 127.116578) 수내로 <class 'str'>
# (37.395786, 126.9645) 평촌역사거리 <class 'str'>
# (37.39919046, 126.9236856) 안양일번가 <class 'str'>
# (37.4002845, 126.92216770000005) 안양역 <class 'str'>
# (37.38405, 127.120257) 분당구청 <class 'str'>
# (37.396242, 126.983977) 의왕포일 <class 'str'>
# (37.386053, 127.121714) 서현N타운 <class 'str'>
# (37.385921, 127.124098) 서현역 <class 'str'>
# (37.385855, 127.125922) 서현 <class 'str'>
# (37.38385, 127.149963) 분당율동공원 <class 'str'>
# (37.391294, 127.077656) 서판교 <class 'str'>
# (37.400269, 126.976145) 인덕원역 <class 'str'>
# (37.38800701, 127.1232512) 서현미래에셋 <class 'str'>
# (37.394263, 127.109227) 판교알파돔시티 <class 'str'>
# (37.395911, 127.113233) 판교역 <class 'str'>
# (37.39504, 127.122363) 분당이매 <class 'str'>
# (37.39731, 127.111294) 판교역로 <class 'str'>
# (37.40042, 127.110572) 판교HIPEX <class 'str'>
# (37.401375, 127.108678) 판교H스퀘어 <class 'str'>
# (37.4028887, 127.0992969) 판교브릿지타워 <class 'str'>
# (37.4037039, 127.115673) 판교봇들마을 <class 'str'>
# (37.41041291, 127.1273) 뉴코아야탑 <class 'str'>
# (37.410845, 127.129806) 야탑글라스 <class 'str'>
# (37.4312614, 126.9033382) 안양석수DT <class 'str'>
# (37.413494, 127.128425) 야탑터미널 <class 'str'>
# (37.42629945, 126.991852) 과천이마트 <class 'str'>
# (37.435072, 126.879143) 광명소하DT <class 'str'>
# (37.428183, 126.991074) 과천 <class 'str'>
# (37.443912, 126.790755) 시흥대야 <class 'str'>
# (37.4097851, 127.26021279999998) 경기광주 <class 'str'>
# (37.44866, 126.883959) 광명소하 <class 'str'>
# (37.462605, 126.880577) 광명하안 <class 'str'>
# (37.4442471, 127.14145710000003) 성남이마트 <class 'str'>
# (37.4433283, 127.15457659999993) 단대오거리역 <class 'str'>
# (37.4739663, 126.86935070000004) 철산로데오 <class 'str'>
# (37.475412, 126.865869) 광명철산 <class 'str'>
# (37.479895, 126.854325) 광명사거리역 <class 'str'>
# (37.4835239, 126.8093104) 역곡역DT <class 'str'>
# (37.485054, 126.782117) 부천 <class 'str'>
# (37.488389, 126.752604) 송내역 <class 'str'>
# (37.492932, 126.78441) 부천심곡DT <class 'str'>
# (37.4963743, 126.76420000000007) 부천중동DT <class 'str'>
# (37.497976, 126.77702) 부천중동 <class 'str'>
# (37.49991091, 126.7449246) 부천플레이도시 <class 'str'>
# (37.473131, 127.141067) 성남위례 <class 'str'>
# (37.504279, 126.756992) 뉴코아부천4층 <class 'str'>
# (37.504022, 126.763939) 중동이마트 <class 'str'>
# (37.5037646, 126.77414390000001) 부천신중동역 <class 'str'>
# (37.50428252, 126.7621682) 현대중동 <class 'str'>
# (37.5051779, 126.75242359999993) 부천상동 <class 'str'>
# (37.505534, 126.762448) 부천시청역 <class 'str'>
# (37.5383807, 127.2039864) 하남신장 <class 'str'>
# (37.540532, 127.216148) 하남시청 <class 'str'>
# (37.544033, 127.225424) 스타필드하남2FR <class 'str'>
# (37.544969, 127.224491) 스타필드하남1F(티바나) <class 'str'>
# (37.545734, 127.223439) 신세계하남2F <class 'str'>
# (37.600112, 126.720441) 김포풍무DT <class 'str'>
# (37.569587, 127.183283) 하남미사 <class 'str'>
# (37.567114, 127.228362) 리버사이드팔당DTR <class 'str'>
# (37.618396, 126.717912) 김포시청 <class 'str'>
# (37.613996, 126.834455) 행신역 <class 'str'>
# (37.624786, 126.696429) 김포감정DT <class 'str'>
# (37.600585, 127.141922) 구리돌다리 <class 'str'>
# (37.60688, 127.13896) 구리인창 <class 'str'>
# (37.63353224, 126.8314538) 화정 <class 'str'>
# (37.6335731, 126.83273269999995) 화정역 <class 'str'>
# (37.640452, 126.677493) 김포장기커낼 <class 'str'>
# (37.6443438, 126.628299) 김포이마트 <class 'str'>
# (37.644239, 126.667908) 김포장기 <class 'str'>
# (37.6411, 126.790987) 백석중앙로 <class 'str'>
# (37.643888, 126.786153) 백석 <class 'str'>
# (37.6439377, 126.7873856) 백석역DT <class 'str'>
# (37.6543091, 126.6841727) 김포운양 <class 'str'>
# (37.646086, 126.893098) 스타필드고양1F고메스트리트 <class 'str'>
# (37.64697, 126.895523) 스타필드고양1FR <class 'str'>
# (37.652965, 126.776768) 마두역 <class 'str'>
# (37.647216, 126.895577) 스타필드고양3F(티바나) <class 'str'>
# (37.647983, 126.896489) 스타필드고양3F잇토피아 <class 'str'>
# (37.654744, 126.77261900000008) 웨스턴돔B <class 'str'>
# (37.656696, 126.77312) 일산동구청 <class 'str'>
# (37.6570742, 126.7880695) 일산백마 <class 'str'>
# (37.66011, 126.76991) 라페스타광장 <class 'str'>
# (37.658155, 126.837639) 원당DT <class 'str'>
# (37.662238, 126.743981) 킨텍스이마트 <class 'str'>
# (37.662091, 126.8009) 일산풍동DT <class 'str'>
# (37.663813, 126.891317) 고양삼송 <class 'str'>
# (37.669903, 126.762657) 일산주엽 <class 'str'>
# (37.671554, 126.758992) 주엽사거리 <class 'str'>
# (37.6479682, 127.1233987) 별내 <class 'str'>
# (37.650317, 127.112364) 별내불암로 <class 'str'>
# (37.673769, 126.786883) 풍산이마트 <class 'str'>
# (37.6753761, 126.7481894) 대화역 <class 'str'>
# (37.6773867, 126.76756990000001) 일산후곡 <class 'str'>
# (37.6779381, 126.812161) 일산식사 <class 'str'>
# (37.6477605, 127.23469380000006) 평내DT <class 'str'>
# (37.6540359, 127.24287989999993) 평내호평역 <class 'str'>
# (37.69192, 126.756991) 일산덕이DT <class 'str'>
# (37.695265, 126.762135) 일산탄현 <class 'str'>
# (37.699706, 126.75709) 일산가구단지 <class 'str'>
# (37.71203, 126.744499) 파주운정 <class 'str'>
# (37.7095394, 126.90529470000001) 고양DT <class 'str'>
# (37.722373, 127.047477) 의정부회룡역DT <class 'str'>
# (37.752207, 126.765613) 파주금릉역 <class 'str'>
# (37.723076, 127.190357) 남양주진접DT <class 'str'>
# (37.737861, 127.046054) 신세계의정부2F <class 'str'>
# (37.737861, 127.046054) 신세계의정부6F <class 'str'>
# (37.73959055, 127.0481313) 의정부중앙 <class 'str'>
# (37.740103, 127.047531) 의정부공원 <class 'str'>
# (37.745353, 127.093792) 의정부민락 <class 'str'>
# (37.769578, 126.696417) 파주P.아울렛 <class 'str'>
# (37.753183, 127.070333) 의정부금오 <class 'str'>
# (37.758477, 127.040289) 의정부녹양DT <class 'str'>
# (37.794628, 127.079196) 양주고읍 <class 'str'>
# (37.8272884, 127.14473079999993) 포천송우 <class 'str'>
# (37.848396, 127.161705) 포천DT <class 'str'>
# (37.888925, 127.057066) 동두천DT <class 'str'>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 스타벅스 API 탐구
#
# ### 광역시, 도를 입력하여 군구 지역 코드 가져오기

# %%
# 지역 코드 가져오기
data_gugun = {
    'rndCod': 'PZ6IH5S3HM',
    'sido_cd': '08' # 경기
}
url = 'http://www.istarbucks.co.kr/store/getGugunList.do'
r = requests.post(url, data_gugun)
df_gugun = json_normalize(json.loads(r.text), 'list')
df_gugun.dropna(axis=0)
df_gugun = df[['gugun_nm', 'gugun_cd']]
print(len(df_gugun))
df_gugun.head(10)
# Out:
# 216
#   gugun_nm gugun_cd
# 0     None     None
# 1     None     None
# 2     None     None
# 3     None     None
# 4     None     None
# 5     None     None
# 6     None     None
# 7     None     None
# 8     None     None
# 9     None     None

# %% [markdown]
# ### 전체 목록에서 필터링 한것과 API를 통해 지역 필터링 결과가 같은지 확인

# %%
# 과천시 지역코드
df_gugun[df_gugun['gugun_nm'] == '과천시']
# Out:
# Empty DataFrame
# Columns: [gugun_nm, gugun_cd]
# Index: []

# %%
# API를 통해 과천시 지점만 가져옴
data_과천 = {
    'ins_lat': '33.4996213', # 제주 시청의 좌표
    'ins_lng': '126.5311884',
    'p_sido_cd':'08', # 01=서울시, 08=경기 ... 16=제주
    'p_gugun_cd':'0803',  # 세부지역 (지정하지 않으면 시/도 전체)
    'in_biz_cd':'',
    'set_date':'',
    'iend':'1000',
}
    
url = 'https://www.istarbucks.co.kr/store/getStore.do'
r = requests.post(url, data=data_과천)
df_과천 = json_normalize(json.loads(r.text), 'list')
df_과천 = df_과천[['s_name', 'lat', 'lot', 'sido_name', 'gugun_name', 'doro_address', 'tel']]
df_과천.head(10)
# Out:
#   s_name          lat         lot sido_name gugun_name  \
# 0  과천이마트  37.42629945  126.991852        경기        과천시
# 1     과천    37.428183  126.991074        경기        과천시
#
#                      doro_address          tel
# 0   경기도 과천시 별양상가3로 11 이마트 1층(별양동)  02-758-8033
# 1  경기도 과천시 중앙로 129, 고려빌딩 1층 (중앙동)  02-758-8369

# %%
# 경기 전체 스벅에서 과천시 지점만 출력
data_경기 = {
    'ins_lat': '33.4996213', # 제주 시청의 좌표
    'ins_lng': '126.5311884',
    'p_sido_cd':'08', # 01=서울시, 08=경기 ... 16=제주
    'p_gugun_cd':'',  # 세부지역 (지정하지 않으면 시/도 전체)
    'in_biz_cd':'',
    'set_date':'',
    'iend':'1000',
}
    
url = 'https://www.istarbucks.co.kr/store/getStore.do'
r = requests.post(url, data=data_경기)
df_경기 = json_normalize(json.loads(r.text), 'list')

df_경기 = df_경기[['s_name', 'lat', 'lot', 'sido_name', 'gugun_name', 'doro_address', 'tel']]
df_경기[df_경기['gugun_name'] == '과천시']
# Out:
#     s_name          lat         lot sido_name gugun_name  \
# 125  과천이마트  37.42629945  126.991852        경기        과천시
# 127     과천    37.428183  126.991074        경기        과천시
#
#                        doro_address          tel
# 125   경기도 과천시 별양상가3로 11 이마트 1층(별양동)  02-758-8033
# 127  경기도 과천시 중앙로 129, 고려빌딩 1층 (중앙동)  02-758-8369

# %% [markdown]
# 이로써 구군 지역 코드로 스타벅스 API를 사용하는 법을 확인함

# %% [markdown]
# ### 스타벅스 API 필터
# - 드라이브 스루, 리저브, 주차, 지하철 인접으로 필요해 보이는 필터들의 API param을 확인함

# %%
# http://www.istarbucks.co.kr/store/store_map.do 에서 개발자 도구로 네트워크 보면서 찾음
# 필터는 일단 필요해 보이는 것만 

filter = {
    'T01':0, # 드라이브 스루
    'T03':1, # 리저브
    'T06':0,
    'T09':0, # 주차
    'T10':0,
    'T12':0,
    'T22':0,
    'P80':0  # 지하철 인접
}

# %%
url = 'https://www.istarbucks.co.kr/store/getStore.do'
r = requests.post(url, data={**data, **filter})
df = json_normalize(json.loads(r.text), 'list')
df[['s_name', 'lat', 'lot', 'sido_name', 'gugun_name', 'doro_address', 'tel']]
# Out:
#         s_name         lat                 lot sido_name gugun_name  \
# 0        수원이비스  37.2592235         127.0313138        경기    수원시 팔달구
# 1         수원인계   37.265499          127.032902        경기    수원시 팔달구
# 2   시흥P.아울렛 3F   37.379754          126.736396        경기        시흥시
# 3           정자   37.365045          127.106119        경기    성남시 분당구
# 4       평촌역사거리   37.395786          126.964500        경기    안양시 만안구
# 5         분당구청    37.38405          127.120257        경기    성남시 분당구
# 6          판교역   37.395911          127.113233        경기    성남시 분당구
# 7        야탑글라스   37.410845          127.129806        경기    성남시 분당구
# 8       부천신중동역  37.5037646  126.77414390000001        경기    부천시 오정구
# 9    스타필드하남2FR   37.544033          127.225424        경기        하남시
# 10  리버사이드팔당DTR   37.567114          127.228362        경기       남양주시
# 11          백석   37.643888          126.786153        경기   고양시 일산서구
# 12   스타필드고양1FR    37.64697          126.895523        경기    고양시 덕양구
#
#                                       doro_address            tel
# 0                        경기도 수원시 팔달구 권광로 132 (인계동)   031-224-5877
# 1                        경기도 수원시 팔달구 권광로 199 (인계동)   031-226-8544
# 2                           경기도 시흥시 서해안로 699 (정왕동)  031-8072-3672
# 3                경기도 성남시 분당구 정자일로 166, SPG센터 (정자동)  031-8022-8559
# 4        경기도 안양시 동안구 시민대로 311 금강스마트 빌딩 1층(관양동1746)   031-426-8918
# 5                         경기도 성남시 분당구 분당로 43 (서현동)   031-708-6758
# 6   경기도 성남시 분당구 대왕판교로606번길 58, 판교푸르지오월드마크 1층 (삼평동)  031-8016-5666
# 7                   경기도 성남시 분당구 성남대로916번길 11 (야탑동)  031-8016-8416
# 8                        경기도 부천시 길주로 281 (중동) 동화빌딩   032-322-4921
# 9                           경기도 하남시 미사대로 750 (신장동)  031-8072-8339
# 10                           경기도 남양주시 와부읍 경강로 772    031-577-3227
# 11                     경기도 고양시 일산동구 중앙로 1059 (백석동)   031-907-6755
# 12                     경기도 고양시 덕양구 고양대로 1955 (동산동)  031-5173-1038
